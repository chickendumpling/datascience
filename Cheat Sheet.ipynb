# %% [markdown]
#  good for NLP is LinearSVC

# %%
#dot notation
# (df
#  .groupby(['year','continent'])
#  [["lifeExp", 'pop']]
#  .mean()
#  .reset_index()
# )

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#pandas

#opening file with tab seperated value
# panas.read_csv("data/gapminder.tsv", sep="\t")
#pd.head(),pd.tail(),pd.sample()


#use bitwise operators
# & for and
# | for or
# dat.loc[(dat["country"]=='Zimbabwe') & (dat["year"]>'1990'), :]

# %%
#style
sns.set_theme()

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#Compare predictions
from sklearn.metrics import classification_report,confusion_matrix
# print(classification_report(y_test,pred))
# print('\n')
# print(confusion_matrix(y_test,pred))

# %%
#Going Through all the files within folder and subfolder in a current directory
#Make sure the folder is in cd

import os

for folder , sub_folders , files in os.walk("Foldername"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    
    print('\n')
    
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
    print('\n')

# %%
#with modfication, searching through text within files (Phone number on this example) 

for folder, sub_folders, files in os.walk("unzip"):
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    print('\n')
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
        
        #getting current file directory
        fpath = os.path.join(folder, f)
        
        #opening the text file
        fileobj = open(fpath,"r")
        
        #converting the text file into string
        text = fileobj.read()
        
        #searching through phone number pattern
        phone = re.search(r'\d\d\d-\d\d\d-\d\d\d\d',text)
        
        #printing the phone number if found
        if phone != None:
            print('Yay phone number found! Phone number is ', phone.group(), " in", fpath)
    print('\n')
